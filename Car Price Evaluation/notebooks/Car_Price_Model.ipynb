# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from xgboost import XGBRegressor

# Set plotting style
sns.set_theme(style="whitegrid")

# %%
# Load Dataset
df = pd.read_csv("../data/data.csv.csv")
print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (10000, 20)
#        brand  year  mileage  engine_size_l  cylinders  horsepower  \
# 0  Chevrolet  2018    71740            1.8          4         128
# 1      Lexus  2017   125578            3.5          6         230
# 2     Subaru  2013   213060            1.8          4         144
# 3    Hyundai  2021    40063            2.0          4         164
# 4      Honda  2019   124780            2.5          4         208
#
#   transmission drivetrain fuel_type body_style  num_doors  seating_capacity  \
# 0    Automatic        AWD  Gasoline        SUV          4                 7
# 1       Manual        FWD  Gasoline     Pickup          4                 3
# 2    Automatic        RWD  Gasoline      Sedan          4                 5
# 3    Automatic        FWD  Gasoline      Sedan          4                 5
# 4    Automatic        AWD  Gasoline        SUV          4                 7
#
#    fuel_economy_mpg  num_owners  accidents_reported service_history  \
# 0              43.2           1                   0       Excellent
# 1              35.4           3                   1       Excellent
# 2              45.3           3                   1            Good
# 3              39.4           2                   1            Good
# 4              34.6           2                   0       Excellent
#
#    condition  warranty_months seller_type  price
# 0  Very Good                0      Dealer  21900
# 1  Excellent                0      Dealer  40500
# 2  Excellent                0      Dealer  11200
# 3       Good                0      Dealer  22200
# 4  Very Good                0      Dealer  27700
